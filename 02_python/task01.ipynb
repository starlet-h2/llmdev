# %%
# 氏名・年齢
name = "山田太郎"
age = 25

# 出力用の複数行をまとめて定義
# f文字列を使用して、変数を埋め込む
message = f"""
はじめまして、 {name} と申します。
年齢は {age} 歳です。来年は {age + 1} 歳になります。
よろしくお願いします。
"""

print(message)
# Out:
# はじめまして、 山田太郎 と申します。
# 年齢は 25 歳です。来年は 26 歳になります。
# よろしくお願いします。
