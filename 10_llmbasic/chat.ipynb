# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# %%
# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ]
)

# レスポンスの表示
pprint(vars(response))
# Out:
# {'_request_id': 'req_9739961d8c864f3d9356a1eea38874eb',
#  'choices': [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='言語モデルを効果的に利用するためのポイントはいくつかあります。以下に主な点を挙げます。\n\n1. **明確な指示を与える**: 言語モデルに具体的で明確なプロンプトを与えることで、期待する答えを得やすくなります。詳細な文脈や背景を提供すると良いでしょう。\n\n2. **コンテキストの利用**: モデルは直前の情報を基に応答を生成します。関連する情報や背景を含めることで、より適切な回答を引き出すことができます。\n\n3. **反復と修正**: 初回の応答が満足できなかった場合、別の角度から質問を考えたり、プロンプトを微調整して再度試みることが重要です。\n\n4. **結果の評価**: モデルが生成したテキストを批判的に評価し、適切かどうかを確認することで、より良い利用ができます。また、情報の正確性や信頼性も考慮する必要があります。\n\n5. **利用の範囲を理解する**: 言語モデルには得意な分野と不得意な分野があります。具体的なデータや専門的な知識が必要な場合、他のリソースと組み合わせて利用することが重要です。\n\n6. **アクセシビリティと倫理**: プライバシーやセキュリティの観点から、個人情報を含む質問やプロンプトは避けるようにします。また、生成された内容が誤解を招かないよう注意が必要です。\n\n7. **創造性を活用する**: 言語モデルは物語の作成やアイデアのブレインストーミングなど、創造的なプロセスにも役立ちます。柔軟な発想で活用することができます。\n\nこれらのポイントを意識しながら、言語モデルを活用することで、より良い結果を得ることができるでしょう。', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None, annotations=[]))],
#  'created': 1776410996,
#  'id': 'chatcmpl-DVXwCROsq3jccuqqYH8E6bDVLuGbP',
#  'model': 'gpt-4o-mini-2024-07-18',
#  'object': 'chat.completion',
#  'service_tier': 'default',
#  'system_fingerprint': 'fp_4debc47fe0',
#  'usage': CompletionUsage(completion_tokens=476, prompt_tokens=18, total_tokens=494, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))}

# %%
# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 言語モデルを効果的に利用するためのポイントはいくつかあります。以下に主な点を挙げます。
#
# 1. **明確な指示を与える**: 言語モデルに具体的で明確なプロンプトを与えることで、期待する答えを得やすくなります。詳細な文脈や背景を提供すると良いでしょう。
#
# 2. **コンテキストの利用**: モデルは直前の情報を基に応答を生成します。関連する情報や背景を含めることで、より適切な回答を引き出すことができます。
#
# 3. **反復と修正**: 初回の応答が満足できなかった場合、別の角度から質問を考えたり、プロンプトを微調整して再度試みることが重要です。
#
# 4. **結果の評価**: モデルが生成したテキストを批判的に評価し、適切かどうかを確認することで、より良い利用ができます。また、情報の正確性や信頼性も考慮する必要があります。
#
# 5. **利用の範囲を理解する**: 言語モデルには得意な分野と不得意な分野があります。具体的なデータや専門的な知識が必要な場合、他のリソースと組み合わせて利用することが重要です。
#
# 6. **アクセシビリティと倫理**: プライバシーやセキュリティの観点から、個人情報を含む質問やプロンプトは避けるようにします。また、生成された内容が誤解を招かないよう注意が必要です。
#
# 7. **創造性を活用する**: 言語モデルは物語の作成やアイデアのブレインストーミングなど、創造的なプロセスにも役立ちます。柔軟な発想で活用することができます。
#
# これらのポイントを意識しながら、言語モデルを活用することで、より良い結果を得ることができるでしょう。

# %%
# 役割や前提の設定
role = "あなたはマーケティング分野に精通したビジネスコンサルタントです。企業の成長をサポートするために、効果的なマーケティング戦略を提供します。"

# メッセージの設定
message = "新製品の発売に向けた効果的なマーケティング戦略を教えてください。"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": message},
    ],
)

# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 新製品の発売に向けた効果的なマーケティング戦略は、対象市場や製品の性質によって異なることがありますが、以下のステップを基にした包括的なアプローチをご提案します。
#
# ### 1. 市場調査とターゲット設定
# - **市場調査**: 顧客のニーズ、競合他社、トレンドを理解するために調査を行います。
# - **ペルソナ設定**: ターゲットとなる顧客のペルソナを定義し、どのような価値を提供できるかを明確にします。
#
# ### 2. 製品ポジショニング
# - **ユニークなセリングプロポジション (USP)**: 製品の特徴を明確にし、競合との差別化を図ります。
# - **ブランディング**: ブランドのストーリーやビジョンを設定し、消費者に感情的なつながりを提供します。
#
# ### 3. マーケティングミックスの設定（4P）
# - **製品 (Product)**: 製品の機能、デザイン、品質を最適化します。
# - **価格 (Price)**: 市場調査に基づいて適切な価格戦略を選定（高価格設定、競争価格、ペネトレーション戦略など）。
# - **流通 (Place)**: オンライン、オフライン、販売チャネルを決定し、アクセスしやすい環境を整えます。
# - **プロモーション (Promotion)**: 多様なプロモーション手法を選定（広告、PR、インフルエンサーとのコラボレーション、ソーシャルメディアキャンペーンなど）。
#
# ### 4. オンラインプレゼンスの強化
# - **ウェブサイト**: 製品情報や購入方法、ブランドストーリーを掲載した魅力的なウェブサイトを構築します。
# - **SEO対策**: 検索エンジン最適化により、製品情報がターゲットユーザーに届くようにします。
#
# ### 5. プレローンチキャンペーンの実施
# - **ティーザーキャンペーン**: 製品の発売前に興味を引くコンテンツを配信し、期待感を高めます。
# - **ソーシャルメディアでのエンゲージメント**: モデルやプロトタイプを使ったインタラクティブな投稿を行い、フォロワーとの対話を促進します。
#
# ### 6. 発売イベントとPR活動
# - **製品のローンチイベント**: オンラインまたはオフラインでの発表イベントを企画し、メディアやインフルエンサーを招待します。
# - **プレスリリース**: 新製品についてのプレスリリースを配信し、メディアの露出を増やします。
#
# ### 7. フィードバックと改善
# - **ローンチ後のデータ収集**: 売上データや顧客のフィードバックを集め、効果を分析します。
# - **改善策の実施**: フィードバックを基に製品やマーケティング戦略の改善を行い、次の施策に活かします。
#
# このようなステップを実施することで、新製品の成功確率を高められます。重要なのは、柔軟な姿勢を持ち、環境の変化に応じて戦略を適宜調整することです。

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    temperature=0.0,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# もちろんです！日本は多様な文化、歴史、自然の美しさが融合した魅力的な国です。以下にいくつかのポイントを紹介します。
#
# ### 1. 文化と伝統
# - **祭り**: 日本各地で行われる伝統的な祭り（例：祇園祭、ねぶた祭り）は、色鮮やかな衣装やパレード、神輿など
# --------------------
# もちろんです！日本は多様な文化、歴史、自然、美食などが魅力的な国です。以下にいくつかのポイントを紹介します。
#
# ### 1. 文化と伝統
# - **祭り**: 日本各地で行われる伝統的な祭り（例：祇園祭、ねぶた祭り）は、地域の文化や歴史を感じることができます。
# - **茶道**:
# --------------------
# もちろんです！日本は多様な文化、歴史、自然、美食などが魅力的な国です。以下にいくつかのポイントを紹介します。
#
# ### 1. 文化と伝統
# - **祭り**: 日本各地で行われる伝統的な祭り（例：祇園祭、ねぶた祭り）は、地域の文化や歴史を感じることができます。
# - **茶道**:

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    presence_penalty=2.0,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# 日本には多くの魅力があります。以下にいくつかのポイントを挙げてみましょう。
#
# ### 1. 自然美
# 日本は四季がはっきりしており、春の桜、夏の緑、秋の紅葉、冬の雪景色など、各季節ごとに異なる美しさを楽しむことができます。特に山々や海岸線の風景は、多
# --------------------
# 日本の魅力は多岐にわたりますが、いくつかのポイントを挙げてみます。
#
# 1. **豊かな文化**: 日本は伝統と現代が融合したユニークな文化を持っています。着物や茶道、和食などの伝統的な文化から、アニメやゲームなどのポップカルチャーまで、多種多様な表現があります。
#
# 2. **美しい自然**
# --------------------
# 日本はその独自の文化、歴史、美しい自然など、多くの魅力を持つ国です。以下にいくつかのポイントを挙げてみます。
#
# 1. **豊かな文化と伝統**: 日本には長い歴史があり、伝統的な祭りや行事（たとえば、お花見や七夕）があります。また、茶道、書道、着物など、日本独自の文化が受

# %%
import tiktoken
from tiktoken.core import Encoding

# OpenAI APIの特定のモデルに対応するトークナイザーを取得
encoding: Encoding = tiktoken.encoding_for_model(MODEL_NAME) # o200k_base

# テキストをトークンIDのリストに変換
tokens = encoding.encode("こんにちは！")
tokens_count = len(tokens)

# トークンの長さとトークンIDを表示
print(f"{tokens_count=}")
print(f"{tokens=}")
# Out:
# tokens_count=2
# tokens=[95839, 3393]

# %%
# トークンの選択度合い
message = """
AさんとBさんで会話してください。
A:あ、Bさんだ。
B:
"""

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    max_tokens=100,
    n=3,
    logit_bias = {95839:8, 3393:8}
)

# 結果を表示
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# B:こんにちは、Aさん！元気ですか？
# --------------------
# B:こんにちは！Aさん、元気ですか？
# --------------------
# B:こんにちは！お久しぶりですね。元気でしたか？

# %%
# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
stream = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    stream=True,
)

for chunk in stream:
    if chunk.choices:
        if chunk.choices[0].delta.content is not None:
            print(chunk.choices[0].delta.content, end="")
# Out:
# 言語モデルを使う上でのポイントはいくつかあります。以下に主なものを挙げます：
#
# 1. **目的の明確化**: 言語モデルを使用する目的を明確にしましょう。情報検索、文章生成、翻訳、要約など、具体的な用途によってアプローチが変わります。
#
# 2. **入力の工夫**: モデルに与える入力（プロンプト）は、その出力に大きく影響します。具体的かつ詳細なプロンプトを作成することで、より望ましい結果を得られます。
#
# 3. **制約の理解**: 言語モデルには限界があります。例えば、最新の情報を持っていない場合や、詳細な知識が必要な専門的な質問には不完全な回答が返されることがあります。
#
# 4. **バイアスへの注意**: 言語モデルは訓練データに基づいており、そのデータに含まれるバイアスを反映することがあります。結果を鵜呑みにせず、批判的に検討する姿勢が重要です。
#
# 5. **フィードバックと改善**: モデルの出力に対してフィードバックを行い、必要に応じてプロンプトや使用法を改善していくと、精度を高めることができます。
#
# 6. **安全性と倫理**: 特に公開する場合は、出力が不適切な内容や誤情報を含む可能性があることを理解し、倫理的な配慮を持って使用することが重要です。
#
# 7. **アプリケーションの適切な設計**: 言語モデルを組み込む際には、ユーザーのニーズに合わせたインターフェースや機能を設計し、使いやすさを重視しましょう。
#
# これらのポイントを考慮することで、言語モデルを効果的に活用することができます。
