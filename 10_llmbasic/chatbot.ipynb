# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# %%
# メッセージを格納するリスト
messages=[]

while(True):
    # ユーザーからの質問を受付
    message = input("メッセージを入力:")
    # 質問が入力されなければ終了
    if message.strip()=="":
        break
    print(f"質問:{message}")

    # メッセージにユーザーからの質問を追加
    messages.append({"role": "user", "content": message.strip()})
    # やりとりが8を超えたら古いメッセージから削除
    if len(messages) > 8:
        del_message = messages.pop(0)

    # APIへリクエスト
    stream = client.chat.completions.create(
        model=MODEL_NAME,
        messages=messages,
        stream=True,
    )

    # 言語モデルからの回答を表示
    response_message = ""
    for chunk in stream:
        if chunk.choices:
            next = chunk.choices[0].delta.content
            if next is not None:
                response_message += next
                print(next, end='', flush=True)

    # メッセージに言語モデルからの回答を追加
    messages.append({"role": "assistant", "content": response_message})

print("\n---ご利用ありがとうございました！---")
# Out:
# 質問:こんにちは！
# こんにちは！どういったお手伝いができますか？質問:初心者にオススメのプログラミング言語を3つ教えて
# 初心者にオススメのプログラミング言語を3つご紹介します。
#
# 1. **Python**:
#    - 読みやすい文法で、学習のハードルが低いです。
#    - データ分析、ウェブ開発、機械学習など幅広い分野で利用されています。
#    - 大きなコミュニティがあり、ライブラリやフレームワークも豊富です。
#
# 2. **JavaScript**:
#    - ウェブ開発に欠かせない言語で、ブラウザ上で動作します。
#    - HTMLやCSSと組み合わせることで、インタラクティブなウェブページを作成できます。
#    - Node.jsを使えばサーバーサイドプログラミングにも対応できます。
#
# 3. **Ruby**:
#    - シンプルで読みやすい文法が特徴です。
#    - Ruby on Railsというウェブアプリケーションフレームワークが人気で、迅速にプロジェクトを立ち上げることができます。
#    - コミュニティが活発で、サポートが得やすいです。
#
# これらの言語はどれも初心者に優しく、さまざまなプロジェクトに対応できるため、学びやすいと思います。興味のある分野に合わせて選んでみてください！質問:1つ目のプログラミング言語の名前は？
# 1つ目のプログラミング言語は「Python」です。
# ---ご利用ありがとうございました！---
